# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd 

df_birmingham = pd.read_csv("CLEANED_DATA/rightmove/rm_properties_birmingham.csv")
df_birmingham
# Out:
#                                                 title  \
# 0                                 Vale Street, Dudley
# 1                      Mellish Road, Walsall, WS4 2EB
# 2                       Woodston Grove, Solihull, B91
# 3                  Rugeley Road, Hazel Slade, Cannock
# 4                        London Road, Lichfield, WS14
# 5                   Worcester Road, Upton Warren, B61
# 6   Brook End Drive, Henley in Arden, Warwickshire...
# 7                                  Dark Lane, Romsley
# 8                Park Hill Road, Harborne, Birmingham
# 9   Ashtree Grove, Lapwing Drive, Hampton-In-Arden...
# 10          Boldmere Road, Boldmere, Sutton Coldfield
# 11  Beausale Lane, Hatton, Warwick, Warwickshire, ...
# 12     Hollywood Lane, Hollywood, Birmingham, B47 5PT
# 13                           Wollescote Road, Pedmore
# 14                Newton Road, Great Barr, Birmingham
# 15                   Darley Green Road, Dorridge, B93
# 16   Tagwell Road, Droitwich Spa, Worcestershire, WR9
# 17             Greenfield Avenue, Balsall Common, CV7
# 18                   Kempson Avenue, Sutton Coldfield
# 19                  Birmingham Road, Sutton Coldfield
# 20  Linthurst Newtown, Blackwell, Bromsgrove, Worc...
# 21  Plantation Lane, Hopwas, Tamworth, Staffordshi...
# 22                              Burnham Road, Wythall
#
#                                              location   price  property_type  \
# 0                                 Vale Street, Dudley  765000       Detached
# 1                      Mellish Road, Walsall, WS4 2EB  765000       Detached
# 2                       Woodston Grove, Solihull, B91  765000       Detached
# 3                  Rugeley Road, Hazel Slade, Cannock  765000       Detached
# 4                        London Road, Lichfield, WS14  760000       Detached
# 5                   Worcester Road, Upton Warren, B61  759500       Detached
# 6   Brook End Drive, Henley in Arden, Warwickshire...  759500       Detached
# 7                                  Dark Lane, Romsley  759000       Detached
# 8                Park Hill Road, Harborne, Birmingham  759000  Semi-Detached
# 9   Ashtree Grove, Lapwing Drive, Hampton-In-Arden...  753000       Detached
# 10          Boldmere Road, Boldmere, Sutton Coldfield  750000  Semi-Detached
# 11  Beausale Lane, Hatton, Warwick, Warwickshire, ...  750000  Semi-Detached
# 12     Hollywood Lane, Hollywood, Birmingham, B47 5PT  750000       Detached
# 13                           Wollescote Road, Pedmore  750000       Detached
# 14                Newton Road, Great Barr, Birmingham  750000       Detached
# 15                   Darley Green Road, Dorridge, B93  750000  Semi-Detached
# 16   Tagwell Road, Droitwich Spa, Worcestershire, WR9  750000       Detached
# 17             Greenfield Avenue, Balsall Common, CV7  750000       Detached
# 18                   Kempson Avenue, Sutton Coldfield  750000       Detached
# 19                  Birmingham Road, Sutton Coldfield  750000       Detached
# 20  Linthurst Newtown, Blackwell, Bromsgrove, Worc...  750000       Detached
# 21  Plantation Lane, Hopwas, Tamworth, Staffordshi...  750000       Detached
# 22                              Burnham Road, Wythall  750000       Detached
#
#     bedrooms  bathrooms   area  \
# 0          5          3    NaN
# 1          5          3    NaN
# 2          4          2    NaN
# 3          5          4    NaN
# 4          4          4    NaN
# 5          5          3  272.0
# 6          5          3    NaN
# 7          4          2    NaN
# 8          4          3    NaN
# 9          4          3  125.0
# 10         5          2    NaN
# 11         3          1    NaN
# 12         5          3  249.0
# 13         4          2    NaN
# 14         6          4    NaN
# 15         3          2    NaN
# 16         4          3  212.0
# 17         5          3  191.0
# 18         4          2  203.0
# 19         5          2    NaN
# 20         4          2    NaN
# 21         6          3    NaN
# 22         5          3    NaN
#
#                                                  link
# 0   https://www.rightmove.co.uk/properties/1731858...
# 1   https://www.rightmove.co.uk/properties/1685362...
# 2   https://www.rightmove.co.uk/properties/1706323...
# 3   https://www.rightmove.co.uk/properties/1703423...
# 4   https://www.rightmove.co.uk/properties/8766033...
# 5   https://www.rightmove.co.uk/properties/1645728...
# 6   https://www.rightmove.co.uk/properties/1629224...
# 7   https://www.rightmove.co.uk/properties/1707567...
# 8   https://www.rightmove.co.uk/properties/1682877...
# 9   https://www.rightmove.co.uk/properties/1709982...
# 10  https://www.rightmove.co.uk/properties/1625380...
# 11  https://www.rightmove.co.uk/properties/1697096...
# 12  https://www.rightmove.co.uk/properties/8761093...
# 13  https://www.rightmove.co.uk/properties/1614663...
# 14  https://www.rightmove.co.uk/properties/1549366...
# 15  https://www.rightmove.co.uk/properties/1728157...
# 16  https://www.rightmove.co.uk/properties/1712086...
# 17  https://www.rightmove.co.uk/properties/1587794...
# 18  https://www.rightmove.co.uk/properties/1653345...
# 19  https://www.rightmove.co.uk/properties/1639430...
# 20  https://www.rightmove.co.uk/properties/1727185...
# 21  https://www.rightmove.co.uk/properties/1712582...
# 22  https://www.rightmove.co.uk/properties/1721713...

# %%
df_birmingham.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          23 non-null     str
#  1   location       23 non-null     str
#  2   price          23 non-null     int64
#  3   property_type  23 non-null     str
#  4   bedrooms       23 non-null     int64
#  5   bathrooms      23 non-null     int64
#  6   area           6 non-null      float64
#  7   link           23 non-null     str
# dtypes: float64(1), int64(3), str(4)
# memory usage: 1.6 KB

# %%
df_birmingham.describe()

# %%
def describe_city_data(city):
    df = pd.read_csv(f"CLEANED_DATA/rightmove/rm_properties_{city.lower()}.csv")
    print(f"Data for {city}:")
    print(df.info())
    display(df.describe())
    print("\n")

list_cities = ["Leicester", "Birmingham", "London", "Glasgow", "Edinburgh", "Newcastle", "Bristol", "Manchester", "Nottingham", "Sheffield", "Liverpool", "Cardiff", "Belfast", "Leeds", "Southampton"]
for city in list_cities:
    try:
        describe_city_data(city)
    except Exception as e:
        print(f"Error describing data for {city}: {e}")
# describe_city_data("Birmingham")

# %% [markdown]
# Price Per Area

# %%
import pandas as pd 

df_birmingham = pd.read_csv("CLEANED_DATA/rightmove/rm_properties_birmingham.csv")

df_birmingham["price_per_area"] = df_birmingham["price"] / df_birmingham["area"]

df_birmingham
# Out:
#                                                 title  \
# 0                                 Vale Street, Dudley
# 1                      Mellish Road, Walsall, WS4 2EB
# 2                       Woodston Grove, Solihull, B91
# 3                  Rugeley Road, Hazel Slade, Cannock
# 4                        London Road, Lichfield, WS14
# 5                   Worcester Road, Upton Warren, B61
# 6   Brook End Drive, Henley in Arden, Warwickshire...
# 7                                  Dark Lane, Romsley
# 8                Park Hill Road, Harborne, Birmingham
# 9   Ashtree Grove, Lapwing Drive, Hampton-In-Arden...
# 10          Boldmere Road, Boldmere, Sutton Coldfield
# 11  Beausale Lane, Hatton, Warwick, Warwickshire, ...
# 12     Hollywood Lane, Hollywood, Birmingham, B47 5PT
# 13                           Wollescote Road, Pedmore
# 14                Newton Road, Great Barr, Birmingham
# 15                   Darley Green Road, Dorridge, B93
# 16   Tagwell Road, Droitwich Spa, Worcestershire, WR9
# 17             Greenfield Avenue, Balsall Common, CV7
# 18                   Kempson Avenue, Sutton Coldfield
# 19                  Birmingham Road, Sutton Coldfield
# 20  Linthurst Newtown, Blackwell, Bromsgrove, Worc...
# 21  Plantation Lane, Hopwas, Tamworth, Staffordshi...
# 22                              Burnham Road, Wythall
#
#                                              location   price  property_type  \
# 0                                 Vale Street, Dudley  765000       Detached
# 1                      Mellish Road, Walsall, WS4 2EB  765000       Detached
# 2                       Woodston Grove, Solihull, B91  765000       Detached
# 3                  Rugeley Road, Hazel Slade, Cannock  765000       Detached
# 4                        London Road, Lichfield, WS14  760000       Detached
# 5                   Worcester Road, Upton Warren, B61  759500       Detached
# 6   Brook End Drive, Henley in Arden, Warwickshire...  759500       Detached
# 7                                  Dark Lane, Romsley  759000       Detached
# 8                Park Hill Road, Harborne, Birmingham  759000  Semi-Detached
# 9   Ashtree Grove, Lapwing Drive, Hampton-In-Arden...  753000       Detached
# 10          Boldmere Road, Boldmere, Sutton Coldfield  750000  Semi-Detached
# 11  Beausale Lane, Hatton, Warwick, Warwickshire, ...  750000  Semi-Detached
# 12     Hollywood Lane, Hollywood, Birmingham, B47 5PT  750000       Detached
# 13                           Wollescote Road, Pedmore  750000       Detached
# 14                Newton Road, Great Barr, Birmingham  750000       Detached
# 15                   Darley Green Road, Dorridge, B93  750000  Semi-Detached
# 16   Tagwell Road, Droitwich Spa, Worcestershire, WR9  750000       Detached
# 17             Greenfield Avenue, Balsall Common, CV7  750000       Detached
# 18                   Kempson Avenue, Sutton Coldfield  750000       Detached
# 19                  Birmingham Road, Sutton Coldfield  750000       Detached
# 20  Linthurst Newtown, Blackwell, Bromsgrove, Worc...  750000       Detached
# 21  Plantation Lane, Hopwas, Tamworth, Staffordshi...  750000       Detached
# 22                              Burnham Road, Wythall  750000       Detached
#
#     bedrooms  bathrooms   area  \
# 0          5          3    NaN
# 1          5          3    NaN
# 2          4          2    NaN
# 3          5          4    NaN
# 4          4          4    NaN
# 5          5          3  272.0
# 6          5          3    NaN
# 7          4          2    NaN
# 8          4          3    NaN
# 9          4          3  125.0
# 10         5          2    NaN
# 11         3          1    NaN
# 12         5          3  249.0
# 13         4          2    NaN
# 14         6          4    NaN
# 15         3          2    NaN
# 16         4          3  212.0
# 17         5          3  191.0
# 18         4          2  203.0
# 19         5          2    NaN
# 20         4          2    NaN
# 21         6          3    NaN
# 22         5          3    NaN
#
#                                                  link  price_per_area
# 0   https://www.rightmove.co.uk/properties/1731858...             NaN
# 1   https://www.rightmove.co.uk/properties/1685362...             NaN
# 2   https://www.rightmove.co.uk/properties/1706323...             NaN
# 3   https://www.rightmove.co.uk/properties/1703423...             NaN
# 4   https://www.rightmove.co.uk/properties/8766033...             NaN
# 5   https://www.rightmove.co.uk/properties/1645728...     2792.279412
# 6   https://www.rightmove.co.uk/properties/1629224...             NaN
# 7   https://www.rightmove.co.uk/properties/1707567...             NaN
# 8   https://www.rightmove.co.uk/properties/1682877...             NaN
# 9   https://www.rightmove.co.uk/properties/1709982...     6024.000000
# 10  https://www.rightmove.co.uk/properties/1625380...             NaN
# 11  https://www.rightmove.co.uk/properties/1697096...             NaN
# 12  https://www.rightmove.co.uk/properties/8761093...     3012.048193
# 13  https://www.rightmove.co.uk/properties/1614663...             NaN
# 14  https://www.rightmove.co.uk/properties/1549366...             NaN
# 15  https://www.rightmove.co.uk/properties/1728157...             NaN
# 16  https://www.rightmove.co.uk/properties/1712086...     3537.735849
# 17  https://www.rightmove.co.uk/properties/1587794...     3926.701571
# 18  https://www.rightmove.co.uk/properties/1653345...     3694.581281
# 19  https://www.rightmove.co.uk/properties/1639430...             NaN
# 20  https://www.rightmove.co.uk/properties/1727185...             NaN
# 21  https://www.rightmove.co.uk/properties/1712582...             NaN
# 22  https://www.rightmove.co.uk/properties/1721713...             NaN

# %% [markdown]
# ## Combine all the cities in Rightmove

# %%
list_cities = ["Leicester", "Birmingham", "London", "Glasgow", "Edinburgh", "Newcastle", "Bristol", "Manchester", "Nottingham", "Sheffield", "Liverpool", "Cardiff", "Belfast", "Leeds", "Southampton"]

df_list = []

for city in list_cities:
    df_temp = pd.read_csv(f"CLEANED_DATA/rightmove/rm_properties_{city.lower()}.csv")
    df_temp["city"] = city
    df_list.append(df_temp)

df_all_cities_original = pd.concat(df_list, ignore_index=True)

# %%
df_all_cities = df_all_cities_original.copy()
# Out:
#                                                  title  \
# 0             Stone Penn Lane, Holwell, Melton Mowbray
# 1                             Hallaton, Hallaton, LE16
# 2                                Wibtoft, Warwickshire
# 3                              Bakehouse Lane, Twyford
# 4                     Main Street, Fleckney, Leicester
# ..                                                 ...
# 328      St. Marys Road, Netley Abbey, Hampshire, SO31
# 329                             Highfield, Southampton
# 330  Beechmount Road, Bassett, Southampton, Hampshi...
# 331                        Pinehurst Road, Southampton
# 332      High Street, Old Bursledon, Southampton, SO31
#
#                                               location      price  \
# 0             Stone Penn Lane, Holwell, Melton Mowbray  1750000.0
# 1                             Hallaton, Hallaton, LE16  1175000.0
# 2                                Wibtoft, Warwickshire   950000.0
# 3                              Bakehouse Lane, Twyford   850000.0
# 4                     Main Street, Fleckney, Leicester   650000.0
# ..                                                 ...        ...
# 328      St. Marys Road, Netley Abbey, Hampshire, SO31  1100000.0
# 329                             Highfield, Southampton   995000.0
# 330  Beechmount Road, Bassett, Southampton, Hampshi...   995000.0
# 331                        Pinehurst Road, Southampton   995000.0
# 332      High Street, Old Bursledon, Southampton, SO31   995000.0
#
#            property_type  bedrooms  bathrooms   area  \
# 0    Equestrian Facility       4.0        2.0  393.0
# 1               Detached       5.0        2.0  393.0
# 2               Detached       5.0        3.0  393.0
# 3               Detached       4.0        3.0  393.0
# 4               Detached       5.0        2.0  393.0
# ..                   ...       ...        ...    ...
# 328        Semi-Detached       4.0        3.0  393.0
# 329             Detached       4.0        2.0  393.0
# 330             Detached       5.0        4.0  393.0
# 331             Detached       5.0        3.0  393.0
# 332             Detached       3.0        2.0  393.0
#
#                                                   link         city  \
# 0    https://www.rightmove.co.uk/properties/1736345...    Leicester
# 1    https://www.rightmove.co.uk/properties/1736637...    Leicester
# 2    https://www.rightmove.co.uk/properties/1736322...    Leicester
# 3    https://www.rightmove.co.uk/properties/1736713...    Leicester
# 4    https://www.rightmove.co.uk/properties/1736208...    Leicester
# ..                                                 ...          ...
# 328  https://www.rightmove.co.uk/properties/1727186...  Southampton
# 329  https://www.rightmove.co.uk/properties/8719473...  Southampton
# 330  https://www.rightmove.co.uk/properties/1720234...  Southampton
# 331  https://www.rightmove.co.uk/properties/1730982...  Southampton
# 332  https://www.rightmove.co.uk/properties/1717312...  Southampton
#
#      price_per_area
# 0       4452.926209
# 1       2989.821883
# 2       2417.302799
# 3       2162.849873
# 4       1653.944020
# ..              ...
# 328     2798.982188
# 329     2531.806616
# 330     2531.806616
# 331     2531.806616
# 332     2531.806616
#
# [333 rows x 10 columns]

# %% [markdown]
# Before the NaNs are filled with median

# %%
df_all_cities
# Out:
#                                                  title  \
# 0             Stone Penn Lane, Holwell, Melton Mowbray
# 1                             Hallaton, Hallaton, LE16
# 2                                Wibtoft, Warwickshire
# 3                              Bakehouse Lane, Twyford
# 4                     Main Street, Fleckney, Leicester
# ..                                                 ...
# 328      St. Marys Road, Netley Abbey, Hampshire, SO31
# 329                             Highfield, Southampton
# 330  Beechmount Road, Bassett, Southampton, Hampshi...
# 331                        Pinehurst Road, Southampton
# 332      High Street, Old Bursledon, Southampton, SO31
#
#                                               location      price  \
# 0             Stone Penn Lane, Holwell, Melton Mowbray  1750000.0
# 1                             Hallaton, Hallaton, LE16  1175000.0
# 2                                Wibtoft, Warwickshire   950000.0
# 3                              Bakehouse Lane, Twyford   850000.0
# 4                     Main Street, Fleckney, Leicester   650000.0
# ..                                                 ...        ...
# 328      St. Marys Road, Netley Abbey, Hampshire, SO31  1100000.0
# 329                             Highfield, Southampton   995000.0
# 330  Beechmount Road, Bassett, Southampton, Hampshi...   995000.0
# 331                        Pinehurst Road, Southampton   995000.0
# 332      High Street, Old Bursledon, Southampton, SO31   995000.0
#
#            property_type  bedrooms  bathrooms  area  \
# 0    Equestrian Facility       4.0        2.0   NaN
# 1               Detached       5.0        2.0   NaN
# 2               Detached       5.0        3.0   NaN
# 3               Detached       4.0        3.0   NaN
# 4               Detached       5.0        2.0   NaN
# ..                   ...       ...        ...   ...
# 328        Semi-Detached       4.0        3.0   NaN
# 329             Detached       4.0        2.0   NaN
# 330             Detached       5.0        4.0   NaN
# 331             Detached       5.0        3.0   NaN
# 332             Detached       3.0        2.0   NaN
#
#                                                   link         city
# 0    https://www.rightmove.co.uk/properties/1736345...    Leicester
# 1    https://www.rightmove.co.uk/properties/1736637...    Leicester
# 2    https://www.rightmove.co.uk/properties/1736322...    Leicester
# 3    https://www.rightmove.co.uk/properties/1736713...    Leicester
# 4    https://www.rightmove.co.uk/properties/1736208...    Leicester
# ..                                                 ...          ...
# 328  https://www.rightmove.co.uk/properties/1727186...  Southampton
# 329  https://www.rightmove.co.uk/properties/8719473...  Southampton
# 330  https://www.rightmove.co.uk/properties/1720234...  Southampton
# 331  https://www.rightmove.co.uk/properties/1730982...  Southampton
# 332  https://www.rightmove.co.uk/properties/1717312...  Southampton
#
# [333 rows x 9 columns]

# %%
# df_missing_values = df_all_cities[].isnull().sum()
df_missing_values = df_all_cities["area"].isnull().sum()
df_missing_values
# Out:
# np.int64(132)

# %%
df_all_cities["area"].dropna().tolist()
# Out:
# [189.0,
#  197.0,
#  151.0,
#  164.0,
#  145.0,
#  146.0,
#  272.0,
#  125.0,
#  249.0,
#  212.0,
#  191.0,
#  203.0,
#  629.0,
#  451.0,
#  486.0,
#  899.0,
#  899.0,
#  484.0,
#  476.0,
#  476.0,
#  605.0,
#  712.0,
#  916.0,
#  1.0,
#  272.0,
#  547.0,
#  467.0,
#  618.0,
#  757.0,
#  799.0,
#  581.0,
#  1.0,
#  3.0,
#  370.0,
#  413.0,
#  595.0,
#  436.0,
#  394.0,
#  414.0,
#  328.0,
#  357.0,
#  328.0,
#  371.0,
#  492.0,
#  373.0,
#  256.0,
#  335.0,
#  340.0,
#  351.0,
#  193.0,
#  258.0,
#  660.0,
#  873.0,
#  561.0,
#  503.0,
#  479.0,
#  405.0,
#  430.0,
#  401.0,
#  404.0,
#  428.0,
#  366.0,
#  400.0,
#  455.0,
#  448.0,
#  405.0,
#  414.0,
#  316.0,
#  204.0,
#  410.0,
#  641.0,
#  257.0,
#  653.0,
#  598.0,
#  569.0,
#  352.0,
#  253.0,
#  276.0,
#  273.0,
#  267.0,
#  426.0,
#  506.0,
#  517.0,
#  828.0,
#  492.0,
#  431.0,
#  562.0,
#  517.0,
#  221.0,
#  279.0,
#  295.0,
#  285.0,
#  367.0,
#  373.0,
#  279.0,
#  372.0,
#  305.0,
#  237.0,
#  293.0,
#  331.0,
#  238.0,
#  644.0,
#  290.0,
#  213.0,
#  213.0,
#  522.0,
#  316.0,
#  290.0,
#  251.0,
#  221.0,
#  140.0,
#  229.0,
#  241.0,
#  229.0,
#  140.0,
#  140.0,
#  229.0,
#  570.0,
#  177.0,
#  177.0,
#  1214.0,
#  534.0,
#  393.0,
#  668.0,
#  465.0,
#  320.0,
#  323.0,
#  334.0,
#  351.0,
#  265.0,
#  278.0,
#  290.0,
#  263.0,
#  1.0,
#  1.0,
#  846.0,
#  781.0,
#  275.0,
#  909.0,
#  396.0,
#  269.0,
#  440.0,
#  538.0,
#  339.0,
#  390.0,
#  399.0,
#  346.0,
#  204.0,
#  340.0,
#  1.0,
#  767.0,
#  440.0,
#  519.0,
#  655.0,
#  447.0,
#  535.0,
#  29.0,
#  317.0,
#  351.0,
#  394.0,
#  401.0,
#  419.0,
#  426.0,
#  338.0,
#  638.0,
#  416.0,
#  370.0,
#  299.0,
#  381.0,
#  295.0,
#  174.0,
#  337.0,
#  95.0,
#  1.0,
#  621.0,
#  861.0,
#  537.0,
#  737.0,
#  679.0,
#  678.0,
#  647.0,
#  874.0,
#  568.0,
#  483.0,
#  531.0,
#  753.0,
#  499.0,
#  465.0,
#  585.0,
#  434.0,
#  451.0,
#  522.0,
#  574.0,
#  541.0,
#  460.0,
#  557.0,
#  313.0,
#  380.0,
#  321.0,
#  289.0,
#  400.0]

# %%
df_all_cities["area"].dropna().median()
# Out:
# np.float64(393.0)

# %%
df_all_cities["area"].dropna().mean()
# Out:
# np.float64(407.9154228855721)

# %%
df_all_cities["area"]  = df_all_cities["area"].fillna(df_all_cities["area"].median(), inplace=True)
# Out:
# /var/folders/zb/ckbmp2j1113556mqnd3w6n0w0000gn/T/ipykernel_98291/1064581598.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df_all_cities["area"]  = df_all_cities["area"].fillna(df_all_cities["area"].median(), inplace=True)

# %% [markdown]
# After the NaNs are filled with media

# %%
df_all_cities
# Out:
#                                                  title  \
# 0             Stone Penn Lane, Holwell, Melton Mowbray
# 1                             Hallaton, Hallaton, LE16
# 2                                Wibtoft, Warwickshire
# 3                              Bakehouse Lane, Twyford
# 4                     Main Street, Fleckney, Leicester
# ..                                                 ...
# 328      St. Marys Road, Netley Abbey, Hampshire, SO31
# 329                             Highfield, Southampton
# 330  Beechmount Road, Bassett, Southampton, Hampshi...
# 331                        Pinehurst Road, Southampton
# 332      High Street, Old Bursledon, Southampton, SO31
#
#                                               location      price  \
# 0             Stone Penn Lane, Holwell, Melton Mowbray  1750000.0
# 1                             Hallaton, Hallaton, LE16  1175000.0
# 2                                Wibtoft, Warwickshire   950000.0
# 3                              Bakehouse Lane, Twyford   850000.0
# 4                     Main Street, Fleckney, Leicester   650000.0
# ..                                                 ...        ...
# 328      St. Marys Road, Netley Abbey, Hampshire, SO31  1100000.0
# 329                             Highfield, Southampton   995000.0
# 330  Beechmount Road, Bassett, Southampton, Hampshi...   995000.0
# 331                        Pinehurst Road, Southampton   995000.0
# 332      High Street, Old Bursledon, Southampton, SO31   995000.0
#
#            property_type  bedrooms  bathrooms   area  \
# 0    Equestrian Facility       4.0        2.0  393.0
# 1               Detached       5.0        2.0  393.0
# 2               Detached       5.0        3.0  393.0
# 3               Detached       4.0        3.0  393.0
# 4               Detached       5.0        2.0  393.0
# ..                   ...       ...        ...    ...
# 328        Semi-Detached       4.0        3.0  393.0
# 329             Detached       4.0        2.0  393.0
# 330             Detached       5.0        4.0  393.0
# 331             Detached       5.0        3.0  393.0
# 332             Detached       3.0        2.0  393.0
#
#                                                   link         city
# 0    https://www.rightmove.co.uk/properties/1736345...    Leicester
# 1    https://www.rightmove.co.uk/properties/1736637...    Leicester
# 2    https://www.rightmove.co.uk/properties/1736322...    Leicester
# 3    https://www.rightmove.co.uk/properties/1736713...    Leicester
# 4    https://www.rightmove.co.uk/properties/1736208...    Leicester
# ..                                                 ...          ...
# 328  https://www.rightmove.co.uk/properties/1727186...  Southampton
# 329  https://www.rightmove.co.uk/properties/8719473...  Southampton
# 330  https://www.rightmove.co.uk/properties/1720234...  Southampton
# 331  https://www.rightmove.co.uk/properties/1730982...  Southampton
# 332  https://www.rightmove.co.uk/properties/1717312...  Southampton
#
# [333 rows x 9 columns]

# %%
df_all_cities["price_per_area"] = df_all_cities["price"] / df_all_cities["area"]

# %%
df_all_cities
# Out:
#                                                  title  \
# 0             Stone Penn Lane, Holwell, Melton Mowbray
# 1                             Hallaton, Hallaton, LE16
# 2                                Wibtoft, Warwickshire
# 3                              Bakehouse Lane, Twyford
# 4                     Main Street, Fleckney, Leicester
# ..                                                 ...
# 328      St. Marys Road, Netley Abbey, Hampshire, SO31
# 329                             Highfield, Southampton
# 330  Beechmount Road, Bassett, Southampton, Hampshi...
# 331                        Pinehurst Road, Southampton
# 332      High Street, Old Bursledon, Southampton, SO31
#
#                                               location      price  \
# 0             Stone Penn Lane, Holwell, Melton Mowbray  1750000.0
# 1                             Hallaton, Hallaton, LE16  1175000.0
# 2                                Wibtoft, Warwickshire   950000.0
# 3                              Bakehouse Lane, Twyford   850000.0
# 4                     Main Street, Fleckney, Leicester   650000.0
# ..                                                 ...        ...
# 328      St. Marys Road, Netley Abbey, Hampshire, SO31  1100000.0
# 329                             Highfield, Southampton   995000.0
# 330  Beechmount Road, Bassett, Southampton, Hampshi...   995000.0
# 331                        Pinehurst Road, Southampton   995000.0
# 332      High Street, Old Bursledon, Southampton, SO31   995000.0
#
#            property_type  bedrooms  bathrooms   area  \
# 0    Equestrian Facility       4.0        2.0  393.0
# 1               Detached       5.0        2.0  393.0
# 2               Detached       5.0        3.0  393.0
# 3               Detached       4.0        3.0  393.0
# 4               Detached       5.0        2.0  393.0
# ..                   ...       ...        ...    ...
# 328        Semi-Detached       4.0        3.0  393.0
# 329             Detached       4.0        2.0  393.0
# 330             Detached       5.0        4.0  393.0
# 331             Detached       5.0        3.0  393.0
# 332             Detached       3.0        2.0  393.0
#
#                                                   link         city  \
# 0    https://www.rightmove.co.uk/properties/1736345...    Leicester
# 1    https://www.rightmove.co.uk/properties/1736637...    Leicester
# 2    https://www.rightmove.co.uk/properties/1736322...    Leicester
# 3    https://www.rightmove.co.uk/properties/1736713...    Leicester
# 4    https://www.rightmove.co.uk/properties/1736208...    Leicester
# ..                                                 ...          ...
# 328  https://www.rightmove.co.uk/properties/1727186...  Southampton
# 329  https://www.rightmove.co.uk/properties/8719473...  Southampton
# 330  https://www.rightmove.co.uk/properties/1720234...  Southampton
# 331  https://www.rightmove.co.uk/properties/1730982...  Southampton
# 332  https://www.rightmove.co.uk/properties/1717312...  Southampton
#
#      price_per_area
# 0       4452.926209
# 1       2989.821883
# 2       2417.302799
# 3       2162.849873
# 4       1653.944020
# ..              ...
# 328     2798.982188
# 329     2531.806616
# 330     2531.806616
# 331     2531.806616
# 332     2531.806616
#
# [333 rows x 10 columns]

# %% [markdown]
# Mean, Median of Price Per Area

# %%
print("Median :", df_all_cities["price_per_area"].median())
print("Mean: ", df_all_cities["price_per_area"].mean())
# Out:
# Median : 4407.5868983957225
# Mean:  114148.6318468736

# %% [markdown]
# ## 3.5 Chepaest Vs Most Expensive Areas

# %%
df_all_cities_groupby_city_mean = df_all_cities.groupby("city")["price_per_area"].mean().reset_index().rename(columns={"price_per_area": "mean_price_per_area"}).sort_values(by="mean_price_per_area", ascending=False)
print("Mean price per area by city:")
display(df_all_cities_groupby_city_mean)

df_all_cities_groupby_city_median = df_all_cities.groupby("city")["price_per_area"].median().reset_index().rename(columns={"price_per_area": "median_price_per_area"}).sort_values(by="median_price_per_area", ascending=False) 
print("Median price per area by city:")
display(df_all_cities_groupby_city_median)
# Out:
# Mean price per area by city:
#            city  mean_price_per_area
# 9        London        849016.606079
# 13    Sheffield        283273.407393
# 6         Leeds        252883.429284
# 5       Glasgow        137839.298593
# 10   Manchester          7578.114935
# 8     Liverpool          5946.952199
# 2       Bristol          5919.261516
# 4     Edinburgh          5827.518067
# 3       Cardiff          5495.558563
# 14  Southampton          4501.313128
# 11    Newcastle          4449.863307
# 12   Nottingham          3285.142054
# 7     Leicester          2522.339753
# 1    Birmingham          2420.790696
# 0       Belfast           763.361457
# Median price per area by city:
#            city  median_price_per_area
# 9        London           40865.210916
# 10   Manchester            7423.580786
# 2       Bristol            5979.643766
# 4     Edinburgh            5979.643766
# 6         Leeds            5414.160744
# 8     Liverpool            5333.889385
# 3       Cardiff            4194.967041
# 13    Sheffield            3859.263999
# 14  Southampton            3816.793893
# 11    Newcastle            3498.374285
# 5       Glasgow            3217.445515
# 12   Nottingham            2957.707243
# 7     Leicester            2417.302799
# 1    Birmingham            1932.569975
# 0       Belfast             318.066158

# %%
! pip install matplotlib
import matplotlib.pyplot as plt

df_all_cities_groupby_city_median.plot(x="city", y="median_price_per_area", kind="bar", figsize=(12, 6), title="Median Price per Area by City")
# Out:
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# <Axes: title={'center': 'Median Price per Area by City'}, xlabel='city'>

# %% [markdown]
# Group by Property Type

# %%
df_all_cities_groupby_property_median = df_all_cities.groupby("property_type")["price_per_area"].median().reset_index().rename(columns={"price_per_area": "median_price_per_area"}).sort_values(by="median_price_per_area", ascending=False) 
print("Median price per area by property type:")
display(df_all_cities_groupby_property_median)
# Out:
# Median price per area by property type:
#           property_type  median_price_per_area
# 9                  Flat           30663.430421
# 17  Serviced Apartments           11363.636364
# 14            Penthouse           10279.700804
# 0             Apartment            7423.580786
# 8            Farm House            6972.111554
# 11                 Land            6361.323155
# 19           Town House            6252.900232
# 13        Not Specified            5591.603053
# 7   Equestrian Facility            5407.124682
# 1   Block of Apartments            5343.511450
# 2    Character Property            5089.058524
# 10                House            5086.513995
# 18             Terraced            4743.083004
# 3         Country House            4452.926209
# 16        Semi-Detached            4312.977099
# 4              Detached            4065.040650
# 6        End of Terrace            4054.054054
# 15                 Plot            3816.793893
# 12  Link Detached House            3502.421407
# 5        Detached Villa            3094.208186

# %%
for city in list_cities:
    print(f"\nAnalyzing data for {city}...")
    df_city = df_all_cities[df_all_cities["city"] == city]
    df_city_groupby_property_median = df_city.groupby("property_type")["price_per_area"].median().reset_index().rename(columns={"price_per_area": "median_price_per_area"}).sort_values(by="median_price_per_area", ascending=False) 
    print(f"Median price per area by property type for {city}:")
    display(df_city_groupby_property_median)
    df_city_groupby_property_median.plot(x="property_type", y="median_price_per_area", kind="bar", figsize=(12, 6), title=f"Median Price per Area by Property Type for {city}")
# Out:
# Analyzing data for Leicester...
# Median price per area by property type for Leicester:
#          property_type  median_price_per_area
# 1  Equestrian Facility            4452.926209
# 3        Semi-Detached            3386.243386
# 0             Detached            2290.076336
# 2  Link Detached House            1628.498728
# Analyzing data for Birmingham...
# Median price per area by property type for Birmingham:
#    property_type  median_price_per_area
# 0       Detached            1946.564885
# 1  Semi-Detached            1908.396947
# Analyzing data for London...
# Median price per area by property type for London:
#    property_type  median_price_per_area
# 0      Apartment           59735.630894
# 3          House           45734.371850
# 6       Terraced           44345.898004
# 5  Semi-Detached           41911.764706
# 2           Flat           41152.263374
# 1       Detached           36089.397424
# 7     Town House           27899.285264
# 4      Penthouse           22191.323693
# Analyzing data for Glasgow...
# Median price per area by property type for Glasgow:
#          property_type  median_price_per_area
# 7  Serviced Apartments          733333.333333
# 5            Penthouse            5155.440415
# 3       End of Terrace            4054.054054
# 0            Apartment            3856.589147
# 6                 Plot            3816.793893
# 8             Terraced            3619.854722
# 4                House            3191.085595
# 2       Detached Villa            3094.208186
# 1             Detached            2970.149254
# 9           Town House            2926.470588
# Analyzing data for Edinburgh...
# Median price per area by property type for Edinburgh:
#          property_type  median_price_per_area
# 5  Serviced Apartments           11363.636364
# 7           Town House            6359.102244
# 3            Penthouse            6234.096692
# 4        Semi-Detached            6188.118812
# 6             Terraced            5983.060748
# 0             Detached            5467.196819
# 1                House            5297.514191
# 2                 Land                    NaN
# Analyzing data for Newcastle...
# Median price per area by property type for Newcastle:
#    property_type  median_price_per_area
# 3  Semi-Detached            4382.951654
# 0       Detached            4300.941187
# 1           Flat            3053.435115
# 2  Not Specified            2531.806616
# 4       Terraced            2506.361323
# Analyzing data for Bristol...
# Median price per area by property type for Bristol:
#    property_type  median_price_per_area
# 2  Semi-Detached            6422.924901
# 4     Town House            6252.900232
# 0       Detached            6087.398374
# 3       Terraced            5120.845921
# 1          House            4607.552336
# Analyzing data for Manchester...
# Median price per area by property type for Manchester:
#    property_type  median_price_per_area
# 3      Penthouse            8587.570621
# 0      Apartment            7423.580786
# 2     Farm House            6972.111554
# 5  Semi-Detached            6361.323155
# 1       Detached            4789.272031
# 4           Plot            2807.017544
# Analyzing data for Nottingham...
# Median price per area by property type for Nottingham:
#          property_type  median_price_per_area
# 5  Serviced Apartments            8396.946565
# 1  Block of Apartments            5343.511450
# 4        Semi-Detached            3734.375000
# 2             Detached            2957.707243
# 0            Apartment            2893.103448
# 6             Terraced            2798.982188
# 3                 Land            1812.191104
# Analyzing data for Sheffield...
# Median price per area by property type for Sheffield:
#         property_type  median_price_per_area
# 2                Land           1.104453e+06
# 3       Not Specified           8.651399e+03
# 0  Character Property           5.089059e+03
# 1            Detached           3.816794e+03
# 4                Plot           3.816794e+03
# 5       Semi-Detached           3.496241e+03
# Analyzing data for Liverpool...
# Median price per area by property type for Liverpool:
#          property_type  median_price_per_area
# 1  Equestrian Facility            6361.323155
# 2                House            6041.984733
# 0             Detached            5298.651252
# 3                 Land                    NaN
# Analyzing data for Cardiff...
# Median price per area by property type for Cardiff:
#    property_type  median_price_per_area
# 2  Semi-Detached            4729.729730
# 0  Country House            4452.926209
# 1       Detached            3927.751586
# Analyzing data for Belfast...
# Median price per area by property type for Belfast:
#    property_type  median_price_per_area
# 1           Flat            2315.789474
# 0       Detached             737.786260
# 2  Semi-Detached             267.175573
# 3       Terraced             228.880407
# Analyzing data for Leeds...
# Median price per area by property type for Leeds:
#          property_type  median_price_per_area
# 1                House            6361.323155
# 2  Link Detached House            5376.344086
# 0             Detached            5318.154599
# Analyzing data for Southampton...
# Median price per area by property type for Southampton:
#    property_type  median_price_per_area
# 3           Plot           11838.799275
# 0       Detached            3882.081157
# 2           Land            3816.793893
# 1          House            3580.882353
# 4  Semi-Detached            2798.982188

# %%
df_all_cities["price_per_area"].describe()
# Out:
# count    3.300000e+02
# mean     1.141486e+05
# std      1.160751e+06
# min      2.162850e+02
# 25%      3.042648e+03
# 50%      4.407587e+03
# 75%      6.361323e+03
# max      1.950000e+07
# Name: price_per_area, dtype: float64

# %% [markdown]
# ## 3.3 Outlier detection

# %%
Q1 = df_all_cities["price_per_area"].quantile(0.25)
Q1
Q3 = df_all_cities["price_per_area"].quantile(0.75)
Q3
IQR = Q3 - Q1
IQR

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# # Below 
df_all_cities[df_all_cities["price_per_area"] < lower_bound]
len(df_all_cities[df_all_cities["price_per_area"] > upper_bound])

outliers = df_all_cities[(df_all_cities["price_per_area"] < lower_bound) | (df_all_cities["price_per_area"] > upper_bound)]
print("Number of outliers:", len(outliers))


df_cleaned_from_outliers = df_all_cities[(df_all_cities["price_per_area"] >= lower_bound) & (df_all_cities["price_per_area"] <= upper_bound)]
df_cleaned_from_outliers
# Out:
# Lower Bound: -1935.3658439784294
# Upper Bound: 11339.336554733114
# Number of outliers: 39
#                                                  title  \
# 0             Stone Penn Lane, Holwell, Melton Mowbray
# 1                             Hallaton, Hallaton, LE16
# 2                                Wibtoft, Warwickshire
# 3                              Bakehouse Lane, Twyford
# 4                     Main Street, Fleckney, Leicester
# ..                                                 ...
# 328      St. Marys Road, Netley Abbey, Hampshire, SO31
# 329                             Highfield, Southampton
# 330  Beechmount Road, Bassett, Southampton, Hampshi...
# 331                        Pinehurst Road, Southampton
# 332      High Street, Old Bursledon, Southampton, SO31
#
#                                               location      price  \
# 0             Stone Penn Lane, Holwell, Melton Mowbray  1750000.0
# 1                             Hallaton, Hallaton, LE16  1175000.0
# 2                                Wibtoft, Warwickshire   950000.0
# 3                              Bakehouse Lane, Twyford   850000.0
# 4                     Main Street, Fleckney, Leicester   650000.0
# ..                                                 ...        ...
# 328      St. Marys Road, Netley Abbey, Hampshire, SO31  1100000.0
# 329                             Highfield, Southampton   995000.0
# 330  Beechmount Road, Bassett, Southampton, Hampshi...   995000.0
# 331                        Pinehurst Road, Southampton   995000.0
# 332      High Street, Old Bursledon, Southampton, SO31   995000.0
#
#            property_type  bedrooms  bathrooms   area  \
# 0    Equestrian Facility       4.0        2.0  393.0
# 1               Detached       5.0        2.0  393.0
# 2               Detached       5.0        3.0  393.0
# 3               Detached       4.0        3.0  393.0
# 4               Detached       5.0        2.0  393.0
# ..                   ...       ...        ...    ...
# 328        Semi-Detached       4.0        3.0  393.0
# 329             Detached       4.0        2.0  393.0
# 330             Detached       5.0        4.0  393.0
# 331             Detached       5.0        3.0  393.0
# 332             Detached       3.0        2.0  393.0
#
#                                                   link         city  \
# 0    https://www.rightmove.co.uk/properties/1736345...    Leicester
# 1    https://www.rightmove.co.uk/properties/1736637...    Leicester
# 2    https://www.rightmove.co.uk/properties/1736322...    Leicester
# 3    https://www.rightmove.co.uk/properties/1736713...    Leicester
# 4    https://www.rightmove.co.uk/properties/1736208...    Leicester
# ..                                                 ...          ...
# 328  https://www.rightmove.co.uk/properties/1727186...  Southampton
# 329  https://www.rightmove.co.uk/properties/8719473...  Southampton
# 330  https://www.rightmove.co.uk/properties/1720234...  Southampton
# 331  https://www.rightmove.co.uk/properties/1730982...  Southampton
# 332  https://www.rightmove.co.uk/properties/1717312...  Southampton
#
#      price_per_area
# 0       4452.926209
# 1       2989.821883
# 2       2417.302799
# 3       2162.849873
# 4       1653.944020
# ..              ...
# 328     2798.982188
# 329     2531.806616
# 330     2531.806616
# 331     2531.806616
# 332     2531.806616
#
# [291 rows x 10 columns]

# %% [markdown]
# ## 3.4 Distribution Analysis

# %% [markdown]
# Visualise the Price Per Area

# %%
for city in list_cities:
    print(f"\nAnalyzing data for {city}...")
    try:
        df_city = df_cleaned_from_outliers[df_cleaned_from_outliers["city"] == city]
        df_city_groupby_property_median = df_city.groupby("property_type")["price_per_area"].median().reset_index().rename(columns={"price_per_area": "median_price_per_area"}).sort_values(by="median_price_per_area", ascending=False) 
        print(f"Median price per area by property type for {city}:")
        display(df_city_groupby_property_median)
        df_city_groupby_property_median.plot(x="property_type", y="median_price_per_area", kind="bar", figsize=(12, 6), title=f"Median Price per Area by Property Type for {city}")
    except Exception as e:
        print(f"Error analyzing data for {city}: {e}")
# Out:
# Analyzing data for Leicester...
# Median price per area by property type for Leicester:
#          property_type  median_price_per_area
# 1  Equestrian Facility            4452.926209
# 3        Semi-Detached            3386.243386
# 0             Detached            2290.076336
# 2  Link Detached House            1628.498728
# Analyzing data for Birmingham...
# Median price per area by property type for Birmingham:
#    property_type  median_price_per_area
# 0       Detached            1946.564885
# 1  Semi-Detached            1908.396947
# Analyzing data for London...
# Median price per area by property type for London:
# Empty DataFrame
# Columns: [property_type, median_price_per_area]
# Index: []
# Error analyzing data for London: index 0 is out of bounds for axis 0 with size 0
#
# Analyzing data for Glasgow...
# Median price per area by property type for Glasgow:
#     property_type  median_price_per_area
# 5       Penthouse            5155.440415
# 3  End of Terrace            4054.054054
# 0       Apartment            3856.589147
# 6            Plot            3816.793893
# 7        Terraced            3300.753049
# 4           House            3191.085595
# 2  Detached Villa            3094.208186
# 1        Detached            2970.149254
# 8      Town House            2926.470588
# Analyzing data for Edinburgh...
# Median price per area by property type for Edinburgh:
#    property_type  median_price_per_area
# 5     Town House            6359.102244
# 2      Penthouse            6234.096692
# 3  Semi-Detached            6188.118812
# 4       Terraced            5983.060748
# 0       Detached            5467.196819
# 1          House            5297.514191
# Analyzing data for Newcastle...
# Median price per area by property type for Newcastle:
#    property_type  median_price_per_area
# 3  Semi-Detached            4382.951654
# 0       Detached            4091.990264
# 1           Flat            3053.435115
# 2  Not Specified            2531.806616
# 4       Terraced            2506.361323
# Analyzing data for Bristol...
# Median price per area by property type for Bristol:
#    property_type  median_price_per_area
# 2  Semi-Detached            6422.924901
# 4     Town House            6252.900232
# 0       Detached            6087.398374
# 3       Terraced            5120.845921
# 1          House            4607.552336
# Analyzing data for Manchester...
# Median price per area by property type for Manchester:
#    property_type  median_price_per_area
# 3      Penthouse            8173.875808
# 0      Apartment            7423.580786
# 2     Farm House            6972.111554
# 5  Semi-Detached            6361.323155
# 1       Detached            4789.272031
# 4           Plot            2807.017544
# Analyzing data for Nottingham...
# Median price per area by property type for Nottingham:
#          property_type  median_price_per_area
# 5  Serviced Apartments            8396.946565
# 1  Block of Apartments            5343.511450
# 4        Semi-Detached            3734.375000
# 2             Detached            2957.707243
# 0            Apartment            2893.103448
# 6             Terraced            2798.982188
# 3                 Land            1812.191104
# Analyzing data for Sheffield...
# Median price per area by property type for Sheffield:
#         property_type  median_price_per_area
# 2                Land            8905.852417
# 3       Not Specified            8651.399491
# 0  Character Property            5089.058524
# 1            Detached            3816.793893
# 4                Plot            3816.793893
# 5       Semi-Detached            3496.240602
# Analyzing data for Liverpool...
# Median price per area by property type for Liverpool:
#          property_type  median_price_per_area
# 1  Equestrian Facility            6361.323155
# 2                House            6041.984733
# 0             Detached            5298.651252
# Analyzing data for Cardiff...
# Median price per area by property type for Cardiff:
#    property_type  median_price_per_area
# 2  Semi-Detached            4729.729730
# 0  Country House            4452.926209
# 1       Detached            3918.495298
# Analyzing data for Belfast...
# Median price per area by property type for Belfast:
#    property_type  median_price_per_area
# 1           Flat            2315.789474
# 0       Detached             737.786260
# 2  Semi-Detached             267.175573
# 3       Terraced             228.880407
# Analyzing data for Leeds...
# Median price per area by property type for Leeds:
#          property_type  median_price_per_area
# 1                House            6361.323155
# 2  Link Detached House            5376.344086
# 0             Detached            5184.331797
# Analyzing data for Southampton...
# Median price per area by property type for Southampton:
#    property_type  median_price_per_area
# 0       Detached            3882.081157
# 2           Land            3816.793893
# 1          House            3580.882353
# 3           Plot            3321.364452
# 4  Semi-Detached            2798.982188

# %% [markdown]
# ### 3.6 Property Type

# %% [markdown]
# Price per area

# %%
df_all_cities_groupby_property_median = df_all_cities.groupby("property_type")["price_per_area"].median().reset_index().rename(columns={"price_per_area": "median_price_per_area"}).sort_values(by="median_price_per_area", ascending=False) 
print(f"Median price per area by property type for {city}:")
display(df_all_cities_groupby_property_median)
df_all_cities_groupby_property_median.plot(x="property_type", y="median_price_per_area", kind="bar", figsize=(12, 6), title=f"Median Price per Area by Property Type")
# Out:
# Median price per area by property type for Southampton:
#           property_type  median_price_per_area
# 9                  Flat           30663.430421
# 17  Serviced Apartments           11363.636364
# 14            Penthouse           10279.700804
# 0             Apartment            7423.580786
# 8            Farm House            6972.111554
# 11                 Land            6361.323155
# 19           Town House            6252.900232
# 13        Not Specified            5591.603053
# 7   Equestrian Facility            5407.124682
# 1   Block of Apartments            5343.511450
# 2    Character Property            5089.058524
# 10                House            5086.513995
# 18             Terraced            4743.083004
# 3         Country House            4452.926209
# 16        Semi-Detached            4312.977099
# 4              Detached            4065.040650
# 6        End of Terrace            4054.054054
# 15                 Plot            3816.793893
# 12  Link Detached House            3502.421407
# 5        Detached Villa            3094.208186
# <Axes: title={'center': 'Median Price per Area by Property Type'}, xlabel='property_type'>

# %%
df_all_cities_groupby_property_mean = df_all_cities.groupby("property_type")["price_per_area"].mean().reset_index().rename(columns={"price_per_area": "median_price_per_area"}).sort_values(by="median_price_per_area", ascending=False) 
print(f"Median price per area by property type for {city}:")
display(df_all_cities_groupby_property_mean)
df_all_cities_groupby_property_mean.plot(x="property_type", y="median_price_per_area", kind="bar", figsize=(12, 6), title=f"Average Price per Area by Property Type")
# Out:
# Median price per area by property type for Southampton:
#           property_type  median_price_per_area
# 18             Terraced          888726.917923
# 11                 Land          553633.709354
# 17  Serviced Apartments          251031.305421
# 4              Detached           57229.969839
# 9                  Flat           23680.785330
# 10                House           15063.679526
# 0             Apartment           13487.424584
# 14            Penthouse           13012.018883
# 19           Town House            9204.928420
# 16        Semi-Detached            8486.665298
# 8            Farm House            6972.111554
# 15                 Plot            6823.640776
# 13        Not Specified            5591.603053
# 7   Equestrian Facility            5407.124682
# 1   Block of Apartments            5343.511450
# 2    Character Property            5089.058524
# 3         Country House            4452.926209
# 6        End of Terrace            4054.054054
# 12  Link Detached House            3502.421407
# 5        Detached Villa            3094.208186
# <Axes: title={'center': 'Average Price per Area by Property Type'}, xlabel='property_type'>

# %% [markdown]
# ## 3.8 Data Quality Metrics

# %%
df_all_cities_original.isnull().mean()*100
# Out:
# title             0.000000
# location          0.000000
# price             0.900901
# property_type     0.000000
# bedrooms          7.507508
# bathrooms         7.807808
# area             39.639640
# link              0.000000
# city              0.000000
# dtype: float64

# %% [markdown]
# ### Outliers dropped

# %%
percentage_records_dropped = (len(outliers)/len(df_all_cities_original))
print(f"Percentage of records dropped due to outliers: {percentage_records_dropped:.2%}")
# Out:
# Percentage of records dropped due to outliers: 11.71%
